# %%
from env.env import Env
from city.city import City
import matplotlib.pyplot as plt

import datetime


env = Env()

temps=[]

for i in range(365):
    env.date += datetime.timedelta(days=1)
    env.update_temp()
    temps.append(env.cities[1].temp)


plt.plot(temps)
